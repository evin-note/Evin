# %%
import numpy as np
import matplotlib as plt
import re
paths = {'x':'C:\\Users\\2019-08\\Downloads\\車いす(エレベータから階段を上る)\\x-2.txt',
         'y':'C:\\Users\\2019-08\\Downloads\\車いす(エレベータから階段を上る)\\y-1.txt',
         'z':'C:\\Users\\2019-08\\Downloads\\車いす(エレベータから階段を上る)\\z.txt'}

# %%
for path in paths:
    with open(paths[path]) as f:
        s = f.read()
        s = re.sub('\d{4}/\d{2}/\d{2}','',s)
        print(re.sub(',','\n',s).splitlines())
        time = s[0]
        t1 = np.arange(0.0, 5.0, 0.1)
        t2 = np.arange(0.0, 5.0, 0.02)
        for i in s:
            plt.plot(i,i)
        plt.show()
# Out:
# [' 10:57:24.909', '-0.182755', ' 10:57:25.005', '-0.162186', ' 10:57:25.106', '-0.060974', ' 10:57:25.206', '0.051544', ' 10:57:25.307', '0.106186', ' 10:57:25.403', '0.034882', ' 10:57:25.503', '0.000488', ' 10:57:25.604', '-0.096481', ' 10:57:25.705', '-0.239349', ' 10:57:25.800', '-0.108688', ' 10:57:25.901', '-0.147552', ' 10:57:26.002', '-0.073730', ' 10:57:26.103', '-0.029037', ' 10:57:26.198', '-0.155045', ' 10:57:26.299', '0.164841', ' 10:57:26.399', '-0.436478', ' 10:57:26.500', '-0.067352', ' 10:57:26.610', '-0.260910', ' 10:57:26.697', '-0.274643', ' 10:57:26.798', '0.001678', ' 10:57:26.898', '-0.040527', ' 10:57:26.994', '-0.099991', ' 10:57:27.095', '0.372177', ' 10:57:27.195', '0.220657', ' 10:57:27.296', '0.138748', ' 10:57:27.392', '0.147934', ' 10:57:27.492', '0.095108', ' 10:57:27.593', '0.097351', ' 10:57:27.694', '0.422714', ' 10:57:27.790', '0.221573', ' 10:57:27.890', '0.399155', ' 10:57:27.991', '0.233505', ' 10:57:28.091', '0.215149', ' 10:57:28.187', '0.2323
# ...
